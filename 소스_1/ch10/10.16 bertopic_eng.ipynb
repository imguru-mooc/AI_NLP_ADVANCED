# %% [markdown]
# 참고
# * https://www.maartengrootendorst.com/blog/bertopic/
# * https://hackernoon.com/nlp-tutorial-topic-modeling-in-python-with-bertopic-372w35l9

# %%
# !pip install bertopic[visualization]
# Out:
# Requirement already satisfied: bertopic[visualization] in c:\users\jikim\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (1.20.3)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (1.3.4)
# Requirement already satisfied: hdbscan>=0.8.28 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (0.8.28)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (0.24.2)
# Requirement already satisfied: umap-learn>=0.5.0 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (0.5.3)
# Requirement already satisfied: plotly>=4.7.0 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (5.8.0)
# Requirement already satisfied: sentence-transformers>=0.4.1 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (2.2.0)
# Requirement already satisfied: pyyaml<6.0 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (5.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\jikim\anaconda3\lib\site-packages (from bertopic[visualization]) (4.62.3)
# Requirement already satisfied: cython>=0.27 in c:\users\jikim\anaconda3\lib\site-packages (from hdbscan>=0.8.28->bertopic[visualization]) (0.29.28)
# Requirement already satisfied: scipy>=1.0 in c:\users\jikim\anaconda3\lib\site-packages (from hdbscan>=0.8.28->bertopic[visualization]) (1.7.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\jikim\anaconda3\lib\site-packages (from hdbscan>=0.8.28->bertopic[visualization]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jikim\anaconda3\lib\site-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jikim\anaconda3\lib\site-packages (from pandas>=1.1.5->bertopic[visualization]) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jikim\anaconda3\lib\site-packages (from plotly>=4.7.0->bertopic[visualization]) (8.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\jikim\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jikim\anaconda3\lib\site-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (2.2.0)
# Requirement already satisfied: huggingface-hub in c:\users\jikim\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.5.1)
# Requirement already satisfied: torchvision in c:\users\jikim\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.12.0)
# Requirement already satisfied: sentencepiece in c:\users\jikim\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.1.96)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\jikim\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.18.0)
# Requirement already satisfied: nltk in c:\users\jikim\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.6.5)
# Requirement already satisfied: torch>=1.6.0 in c:\users\jikim\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (1.11.0)
# Requirement already satisfied: typing-extensions in c:\users\jikim\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.10.0.2)
# Requirement already satisfied: colorama in c:\users\jikim\anaconda3\lib\site-packages (from tqdm>=4.41.1->bertopic[visualization]) (0.4.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\jikim\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\jikim\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (21.0)
# Requirement already satisfied: filelock in c:\users\jikim\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.3.1)
# Requirement already satisfied: requests in c:\users\jikim\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.26.0)
# Requirement already satisfied: sacremoses in c:\users\jikim\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jikim\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2021.8.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jikim\anaconda3\lib\site-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.4)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\jikim\anaconda3\lib\site-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.5.7)
# Requirement already satisfied: numba>=0.49 in c:\users\jikim\anaconda3\lib\site-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.54.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\jikim\anaconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.37.0)
# Requirement already satisfied: setuptools in c:\users\jikim\anaconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (58.0.4)
# Requirement already satisfied: click in c:\users\jikim\anaconda3\lib\site-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (8.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jikim\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jikim\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jikim\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jikim\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jikim\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (8.4.0)
# WARNING: bertopic 0.10.0 does not provide the extra 'visualization'

# %% [markdown]
# SBERT를 이용한 토픽 모델인 BERTopic은 별도 논문은 나오지 않은 모델이지만, 개발자는 BERTopic이 LDA를 대체할 수 있을만큼의 기술이라고 확신한다고 합니다. 여기서는 BERT 기반의 토픽 모델링 구현체인 BERTopic의 간단한 사용 방법에 대해서 다룹니다.

# %% [markdown]
# # 1. BERTopic

# %% [markdown]
# BERTopic은 BERT embeddings과 클래스 기반(class-based) TF-IDF를 활용하여 주제 설명에서 중요한 단어를 유지하면서도 쉽게 해석할 수 있는 조밀한 클러스터를 만드는 토픽 모델링 기술입니다. BERTopic 알고리즘은 크게 세 가지 과정을 거칩니다.

# %% [markdown]
# **1) 텍스트 데이터를 SBERT로 임베딩합니다.**
# 알고리즘은 SBERT를 사용하여 문서를 임베딩합니다. 이때, BERTopic은 기본적으로 아래의 BERT들을 사용합니다.
#
# * **"paraphrase-MiniLM-L6-v2"** : 영어 데이터로 학습된 SBERT
# * **"paraphrase-multilingual-MiniLM-L12-v2"** : 50개 이상의 언어로 학습된 다국어 SBERT

# %% [markdown]
# **2) 문서를 군집화합니다.**
# UMAP을 사용하여 임베딩의 차원을 줄이고 HDBSCAN 기술을 사용하여 차원 축소된 임베딩을 클러스터링하고 의미적으로 유사한 문서 클러스터를 생성합니다.

# %% [markdown]
# **3) 토픽 표현을 생성**
# 마지막 단계는 클래스 기반 TF-IDF로 토픽을 추출합니다.

# %% [markdown]
# # 2. 데이터 로드

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
# 상위 5개의 샘플 출력
docs[:5]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
#  'My brother is in the market for a high-performance video card that supports\nVESA local bus with 1-2MB RAM.  Does anyone have suggestions/ideas on:\n\n  - Diamond Stealth Pro Local Bus\n\n  - Orchid Farenheit 1280\n\n  - ATI Graphics Ultra Pro\n\n  - Any other high-performance VLB card\n\n\nPlease post or email.  Thank you!\n\n  - Matt\n',
#  '\n\n\n\n\tFinally you said what you dream about. Mediterranean???? That was new....\n\tThe area will be "greater" after some years, like your "holocaust" numbers......\n\n\n\n\n\t\t*****\n\tIs\'t July in USA now????? Here in Sweden it\'s April and still cold.\n\tOr have you changed your calendar???\n\n\n\t\t\t\t\t\t    ****************\n\t\t\t\t\t\t    ******************\n\t\t\t    ***************\n\n\n\tNOTHING OF THE MENTIONED IS TRUE, BUT LET SAY IT\'s TRUE.\n\t\n\tSHALL THE AZERI WOMEN AND CHILDREN GOING TO PAY THE PRICE WITH\n\t\t\t\t\t\t    **************\n\tBEING RAPED, KILLED AND TORTURED BY THE ARMENIANS??????????\n\t\n\tHAVE YOU HEARDED SOMETHING CALLED: "GENEVA CONVENTION"???????\n\tYOU FACIST!!!!!\n\n\n\n\tOhhh i forgot, this is how Armenians fight, nobody has forgot\n\tyou killings, rapings and torture against the Kurds and Turks once\n\tupon a time!\n      \n       \n\n\nOhhhh so swedish RedCross workers do lie they too? What ever you say\n"regional killer", if you don\'t like the person then shoot him that\'s your policy.....l\n\n\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\tConfused?????\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n        Search Turkish planes? You don\'t know what you are talking about.\ti\n        Turkey\'s government has announced that it\'s giving weapons  <-----------i\n        to Azerbadjan since Armenia started to attack Azerbadjan\t\t\n        it self, not the Karabag province. So why search a plane for weapons\t\n        since it\'s content is announced to be weapons?   \n\n\tIf there is one that\'s confused then that\'s you! We have the right (and we do)\n\tto give weapons to the Azeris, since Armenians started the fight in Azerbadjan!\n \n\n\n\tShoot down with what? Armenian bread and butter? Or the arms and personel \n\tof the Russian army?\n\n\n',
#  "\nThink!\n\nIt's the SCSI card doing the DMA transfers NOT the disks...\n\nThe SCSI card can do DMA transfers containing data from any of the SCSI devices\nit is attached when it wants to.\n\nAn important feature of SCSI is the ability to detach a device. This frees the\nSCSI bus for other devices. This is typically used in a multi-tasking OS to\nstart transfers on several devices. While each device is seeking the data the\nbus is free for other commands and data transfers. When the devices are\nready to transfer the data they can aquire the bus and send the data.\n\nOn an IDE bus when you start a transfer the bus is busy until the disk has seeked\nthe data and transfered it. This is typically a 10-20ms second lock out for other\nprocesses wanting the bus irrespective of transfer time.\n",
#  '1)    I have an old Jasmine drive which I cannot use with my new system.\n My understanding is that I have to upsate the driver with a more modern\none in order to gain compatability with system 7.0.1.  does anyone know\nof an inexpensive program to do this?  ( I have seen formatters for <$20\nbuit have no idea if they will work)\n \n2)     I have another ancient device, this one a tape drive for which\nthe back utility freezes the system if I try to use it.  THe drive is a\njasmine direct tape (bought used for $150 w/ 6 tapes, techmar\nmechanism).  Essentially I have the same question as above, anyone know\nof an inexpensive beckup utility I can use with system 7.0.1']

# %%
print('총 문서의 수 :', len(docs))
# Out:
# 총 문서의 수 : 18846

# %% [markdown]
# # 3. 토픽 모델링

# %% [markdown]
# BERTopic의 fit_transform 메소드에 문자열들의 리스트를 입력으로 넣으면 토픽 모델링을 수행합니다.

# %%
model = BERTopic()
topics, probabilities = model.fit_transform(docs)

# %%
print('각 문서의 토픽 번호 리스트 :',len(topics))
print('첫번째 문서의 토픽 번호 :', topics[0])
# Out:
# 각 문서의 토픽 번호 리스트 : 18846
# 첫번째 문서의 토픽 번호 : 0

# %% [markdown]
# get_topic_info() 메소드를 사용하여 토픽의 개수, 토픽의 크기, 각 토픽에 할당된 단어들을 일부 볼 수 있습니다.

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                  Name
# 0       -1   6560                      -1_to_is_the_and
# 1        0   1825                  0_game_team_he_games
# 2        1    601         1_key_clipper_chip_encryption
# 3        2    534              2_dank_vielen_ites_hello
# 4        3    467            3_israel_israeli_jews_arab
# ..     ...    ...                                   ...
# 198    197     11           197_std_saturn_dealer_price
# 199    198     10   198_playback_quicktime_movie_frames
# 200    199     10  199_quid_answer_enterprises_colonies
# 201    200     10             200_zane_2ti_church_faith
# 202    201     10                  201_isa_bus_ide_ksec
#
# [203 rows x 3 columns]

# %% [markdown]
# Count 열의 값을 모두 합하면 총 문서의 수입니다.

# %%
model.get_topic_info()['Count'].sum()
# Out:
# 18846

# %% [markdown]
# 위의 출력에서 Topic -1이 가장 큰 것으로 보입니다. -1은 토픽이 할당되지 않은 모든 이상치 문서(outliers)들을 나타냅니다. 현재 0번 토픽부터 210번 토픽까지 있는데, 임의로 5번 토픽에 대해서 단어들을 출력해봅시다.
#
# get_topic() 메소드의 입력으로 보고자하는 토픽의 번호를 넣어줍니다.

# %%
model.get_topic(5)
# Out:
# [('bike', 0.01514938952419733),
#  ('riding', 0.011757758161371722),
#  ('ride', 0.011223335545658741),
#  ('my', 0.009132583108013613),
#  ('lane', 0.008151119493536162),
#  ('you', 0.007776708335600023),
#  ('passenger', 0.0074305908408969145),
#  ('driving', 0.007292051979090071),
#  ('car', 0.0072082464023649415),
#  ('your', 0.007191589773747181)]

# %% [markdown]
# # 4. 토픽 시각화

# %% [markdown]
# BerTopic을 사용하면 LDAvis와 매우 유사한 방식으로 생성된 토픽을 시각화할 수 있습니다. 시각화를 통해 생성된 토픽에 대해 더 많은 통찰력을 얻을 수 있습니다. 우선 visualize_topics() 메소드로 시각화를 진행해봅시다.

# %%
model.visualize_topics()
# Out:
# <div>                            <div id="2ddeba18-1c84-4015-b9a8-498c9bea49fc" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ddeba18-1c84-4015-b9a8-498c9bea49fc")) {                    Plotly.newPlot(                        "2ddeba18-1c84-4015-b9a8-498c9bea49fc",                        [{"customdata":[[1,"key | clipper | chip | encryption | keys",601],[2,"dank | vielen | ites | hello | cheek",534],[3,"israel | israeli | jews | arab | jewish",467],[4,"gun | guns | firearms | amendment | militia",380],[5,"bike | riding | ride | my | lane",259],[6,"you | context | jim | post | your",230],[7,"jpeg | image | gif | images | format",209],[8,"car | cars | mustang | ford | engine",192],[9,"ram | drive | sale | os | price",187],[10,"bike | tires | bikes | tire | miles",181],[11,"amp | audio | condition | asking | stereo",164],[12,"printer | print | hp | deskjet | printers",147],[13,"space | launch | station | shuttle | nasa",145],[14,"graphics | 3d | conference | visualization | nok",138],[15,"drive | drives | disk | controller | bios",133],[16,"window | widget | application | event | expose",127],[17,"windows | mbytes | dos | ms | paradox",120],[18,"atheists | atheism | god | atheist | belief",119],[19,"health | tobacco | cesarean | smokeless | malaria",118],[20,"armenian | turkish | armenians | genocide | turkey",105],[21,"moral | morality | objective | immoral | morals",98],[22,"drive | drives | disks | toshiba | scsi",89],[23,"islam | quran | islamic | rushdie | muslims",88],[24,"medical | patients | medicine | doctors | doctor",88],[25,"men | kinsey | sex | homosexual | gay",84],[26,"monitor | vga | monitors | horizontal | nec",84],[27,"den | polygon | points | algorithm | xxxx",83],[28,"error | symbol | undefined | libxmulibxmuso | doug",81],[29,"games | joystick | sega | game | cd",80],[30,"serbs | muslims | stephanopoulos | mr | bosnia",79],[31,"dos | pom | cds | mpc | cd",76],[32,"pain | migraine | diet | cancer | patients",76],[33,"msg | food | chinese | foods | taste",75],[34,"simms | simm | ram | vram | meg",74],[35,"homosexuality | homosexual | homosexuals | paul | sex",73],[36,"fire | fbi | stove | started | fires",73],[37,"ham | radio | interference | antenna | amp",70],[38,"modem | fax | modems | courier | v32bis",70],[39,"drivers | card | driver | diamond | video",68],[40,"batf | warrant | raid | assault | they",66],[41,"tax | taxes | income | deficit | clinton",65],[42,"fonts | font | truetype | tt | atm",63],[43,"remote | rx | xterm | server | xb",62],[44,"db | mov | windows | swap | blbh",61],[45,"scsi | scsi2 | scsi1 | ide | controller",58],[46,"os2 | windows | nt | apps | run",56],[47,"science | theory | scientific | methodology | evidence",54],[48,"sky | advertising | billboard | billboards | light",52],[49,"koresh | batf | fbi | compound | children",51],[50,"books | book | anania | shirak | orbeli",50],[51,"candida | yeast | infection | infections | yogurt",49],[52,"mary | her | she | bernadette | sin",49],[53,"battery | batteries | concrete | discharge | temperature",49],[54,"paint | wax | plastic | scratches | finish",48],[55,"were | they | armenians | azerbaijan | her",48],[56,"leds | uv | blue | light | boards",46],[57,"hell | eternal | heaven | jesus | god",46],[58,"copy | protection | program | software | backup",46],[59,"books | scripture | canon | bible | hebrew",46],[60,"radar | detector | detectors | ka | pavement",45],[61,"hst | reboost | mission | shuttle | orbit",43],[62,"mouse | driver | mice | ball | mousecom",43],[63,"newsgroup | vote | voting | votes | newsgroups",43],[64,"water | dept | energy | phd | environmental",42],[65,"space | venus | spacecraft | planets | solar",42],[66,"kuwait | iraq | iran | gulf | arabia",41],[67,"greek | greece | turkish | gree ...

# %% [markdown]
# # 5. 단어 시각화

# %% [markdown]
# Visualization_barchart() 메소드는 c-TF-IDF 점수에서 막대 차트를 만들어 각 토픽에 대해 선택된 단어들을 표시합니다. 각 토픽에 대해서 선택된 단어들을 비교할 수 있습니다.

# %%
model.visualize_barchart()
# Out:
# <div>                            <div id="76aaf44d-a853-4dba-a17b-a639d19df2dc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76aaf44d-a853-4dba-a17b-a639d19df2dc")) {                    Plotly.newPlot(                        "76aaf44d-a853-4dba-a17b-a639d19df2dc",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006447647554958595,0.007374023561213697,0.007391839413953397,0.009267339085183514,0.01066346855007864],"y":["players  ","games  ","he  ","team  ","game  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.009376275010097275,0.011131633788717123,0.01146919954309595,0.012097296351028016,0.013813186547340267],"y":["keys  ","encryption  ","chip  ","clipper  ","key  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.2660980182115931,0.2740807446409919,0.2853885334588355,0.3331852051459196,0.3331852051459196],"y":["cheek  ","hello  ","ites  ","vielen  ","dank  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008432062248551546,0.010632826919876357,0.011610762107953263,0.014369002782773987,0.018964804030769906],"y":["jewish  ","arab  ","jews  ","israeli  ","israel  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.006819542818438196,0.007084225649995424,0.009151768903055524,0.010140229111415903,0.018142274527904494],"y":["militia  ","amendment  ","firearms  ","guns  ","gun  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.008151119493536162,0.009132583108013613,0.011223335545658741,0.011757758161371722,0.01514938952419733],"y":["lane  ","my  ","ride  ","riding  ","bike  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.009520333035296065,0.00959271166385646,0.010069909967196193,0.010077533484463169,0.011636547079931153],"y":["your  ","post  ","jim  ","context  ","you  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013068445777768119,0.014898395948649825,0.017124091242360577,0.027682055909901988,0.02993504585098275],"y":["format  ","images  ","gif  ","image  ","jpeg  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666 ...

# %% [markdown]
# # 6. 토픽 유사도 시각화

# %% [markdown]
# 각 토픽들이 서로 얼마나 유사한지 시각화할 수도 있습니다. visualize_heatmap() 메소드를 사용하여 히트맵을 시각화합니다.
# 해당 히트맵의 원하는 위치에 마우스를 갖다대면 실질적인 유사도 값을 확인할 수 있습니다.

# %%
model.visualize_heatmap()
# Out:
# <div>                            <div id="55fbc0a6-b6fd-4ce5-8e34-6b18197167d1" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55fbc0a6-b6fd-4ce5-8e34-6b18197167d1")) {                    Plotly.newPlot(                        "55fbc0a6-b6fd-4ce5-8e34-6b18197167d1",                        [{"coloraxis":"coloraxis","name":"0","x":["0_game_team_he","1_key_clipper_chip","2_dank_vielen_ites","3_israel_israeli_jews","4_gun_guns_firearms","5_bike_riding_ride","6_you_context_jim","7_jpeg_image_gif","8_car_cars_mustang","9_ram_drive_sale","10_bike_tires_bikes","11_amp_audio_condition","12_printer_print_hp","13_space_launch_station","14_graphics_3d_conference","15_drive_drives_disk","16_window_widget_application","17_windows_mbytes_dos","18_atheists_atheism_god","19_health_tobacco_cesarean","20_armenian_turkish_armenians","21_moral_morality_objective","22_drive_drives_disks","23_islam_quran_islamic","24_medical_patients_medicine","25_men_kinsey_sex","26_monitor_vga_monitors","27_den_polygon_points","28_error_symbol_undefined","29_games_joystick_sega","30_serbs_muslims_stephanopo...","31_dos_pom_cds","32_pain_migraine_diet","33_msg_food_chinese","34_simms_simm_ram","35_homosexuality_homosexual...","36_fire_fbi_stove","37_ham_radio_interference","38_modem_fax_modems","39_drivers_card_driver","40_batf_warrant_raid","41_tax_taxes_income","42_fonts_font_truetype","43_remote_rx_xterm","44_db_mov_windows","45_scsi_scsi2_scsi1","46_os2_windows_nt","47_science_theory_scientific","48_sky_advertising_billboard","49_koresh_batf_fbi","50_books_book_anania","51_candida_yeast_infection","52_mary_her_she","53_battery_batteries_concrete","54_paint_wax_plastic","55_were_they_armenians","56_leds_uv_blue","57_hell_eternal_heaven","58_copy_protection_program","59_books_scripture_canon","60_radar_detector_detectors","61_hst_reboost_mission","62_mouse_driver_mice","63_newsgroup_vote_voting","64_water_dept_energy","65_space_venus_spacecraft","66_kuwait_iraq_iran","67_greek_greece_turkish","68_prozac_drugs_nutrition","69_clutch_shift_gear","70_miles_power_amfm","71_ra_satan_god","72_hotel_voucher_package","73_drugs_drug_cocaine","74_oort_cloud_grbs","75_motif_widgets_bindings","76_trial_weaver_spence","77_mhz_speed_486dx250","78_reno_president_waco","79_dog_dogs_bike","80_insurance_geico_car","81_deleted_stuff_hurts","82_professors_university_sc...","83_graphics_ray_3d","84_ripem_key_des","85_fan_cpu_heat","86_penalty_cruel_punishment","87_clinton_bush_quayle","88_marriage_married_marry","89_gay_sexual_homosexuality","90_diesel_diesels_fuel","91_jehovah_elohim_lord","92_kirlian_photography_leaf","93_stuffit_files_ftp","94_countersteering_bike_mot...","95_insurance_health_private","96_mhz_clock_cpu","97_jesus_christianity_life","98_government_libertarians_...","99_hacker_computer_hackers","100_scanner_logitech_ocr","101_letter_usenet_internet","102_irq_com3_port","103_tape_backup_tapes","104_pope_church_schism","105_modem_cts_dce","106_schools_moment_silence","107_myers_stephanopoulos_pr...","108_xv_copyright_donation","109_tomb_jesus_resurrection","110_monitor_off_turn","111_polysyllabic_abo_b4","112_1st_wolverine_comics","113_km_constant_orbit","114_ghostscript_postscript_...","115_oil_drain_leaks","116_maxaxaxaxaxaxaxaxaxaxax...","117_helmet_liner_foam","118_aaron_baptism_sin","119_lens_camera_nikon","120_board_connector_chip","121_dos_cluster_fat","122_gc_draw_mydisplay","123_pds_nubus_lc","124_dial_number_phone","125_midi_driver_sound","126_clinton_screw_step","127_clock_date_bios","128_scope_scopes_oscilloscope","129_existence_genetic_br","130_card_ati_cards","131_celp_dsp_voice","132_prophecies_prophecy_lord","133_mode_vesa_modes","134_lock_kryptonite_cable","135_monitor_problem_apple","136_shaft_wheelie_wheelies","13 ...

# %% [markdown]
# # 7. 토픽의 수 정하기

# %% [markdown]
# 때때로 너무 많은 토픽이 생성되거나 너무 적은 토픽이 생성될 수 있습니다. 토픽의 수를 직접 정하고 싶다면 몇 가지 방법이 존재합니다.

# %% [markdown]
# 첫번째 방법은 모델 객체 생성 시에 nr_topics 값으로 원하는 토픽 수를 입력하여 원하는 토픽의 수를 설정할 수 있습니다. BerTopic은 유사한 토픽들을 찾아 하나의 토픽으로 병합합니다.

# %%
model = BERTopic(nr_topics=20)
topics, probabilities = model.fit_transform(docs)

# %%
model.visualize_topics()
# Out:
# <div>                            <div id="86ab0ed5-9b48-4bdf-80fa-b9c9231503f2" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86ab0ed5-9b48-4bdf-80fa-b9c9231503f2")) {                    Plotly.newPlot(                        "86ab0ed5-9b48-4bdf-80fa-b9c9231503f2",                        [{"customdata":[[1,"the | to | of | be | and",592],[2,"ites | cheek | yep | why | huh",524],[3,"the | of | israel | to | in",477],[4,"drive | scsi | drives | the | ide",411],[5,"the | they | to | that | fbi",349],[6,"bike | the | to | and | it",298],[7,"of | and | the | to | for",293],[8,"car | the | and | it | cars",281],[9,"for | condition | sale | with | and",246],[10,"is | that | of | god | to",228],[11,"gun | the | to | of | in",219],[12,"card | drivers | the | driver | windows",208],[13,"that | of | the | to | homosexual",192],[14,"image | jpeg | images | and | gif",188],[15,"modem | the | to | port | serial",176],[16,"window | the | to | is | widget",159],[17,"printer | print | hp | the | deskjet",155],[18,"you | to | of | that | the",148],[19,"the | of | turkish | and | armenian",145]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[592,524,477,411,349,298,293,281,246,228,219,208,192,188,176,159,155,148,145],"sizemode":"area","sizeref":0.37,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[9.294312477111816,3.9622912406921387,11.294971466064453,1.089255452156067,10.855080604553223,12.639337539672852,9.748334884643555,12.345888137817383,-1.1109695434570312,4.818019866943359,9.739078521728516,-0.5534979104995728,4.698959827423096,-0.9069949388504028,0.9560365080833435,1.4743797779083252,-1.0761499404907227,4.375431537628174,11.658028602600098],"xaxis":"x","y":[-2.8900861740112305,16.342670440673828,-3.569908618927002,-1.6867411136627197,-3.324144124984741,-9.224844932556152,-2.9941494464874268,-8.992254257202148,-7.664115905761719,15.99218463897705,-2.6296865940093994,-7.340407848358154,15.724984169006348,-7.9036126136779785,-2.0321896076202393,-1.8909207582473755,-7.260556697845459,16.241008758544922,-3.825958251953125],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.22222222222222 ...

# %% [markdown]
# 또 다른 방법은 모델이 자동으로 토픽의 수를 줄이도록 설정하는 것입니다. 이 옵션을 사용하려면 모델 객체 생성 시에 "nr_topics"의 값을 "auto"로 설정하면 됩니다.

# %%
model = BERTopic(nr_topics="auto")
topics, probabilities = model.fit_transform(docs)

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#     Topic  Count                              Name
# 0       0   8612                   0_the_to_of_and
# 1      -1   7226                  -1_the_to_of_and
# 2       1    456         1_israel_israeli_jews_the
# 3       2    158        2_cancer_medical_of_health
# 4       3    152                  3_gun_guns_in_of
# ..    ...    ...                               ...
# 67     66     10  66_xmodmap_modifiers_key_numlock
# 68     67     10        67_icon_icons_click_change
# 69     68     10        68_ear_wax_hearing_syringe
# 70     69     10       69_uv_bulb_bulbs_flashlight
# 71     70     10       70_corn_cereals_sp_seizures
#
# [72 rows x 3 columns]

# %% [markdown]
# 토픽의 개수를 지정하지 않았을 때는 0번 토픽부터 210번 토픽까지 총 211개의 토픽이 존재하였으나, 자동으로 토픽의 수가 줄어들도록 설정하자 토픽의 수가 0번부터 143번까지 총 144개로 줄어든 것을 확인할 수 있습니다.

# %% [markdown]
# # 8. 임의의 문서에 대한 예측

# %%
new_doc = docs[0]
print(new_doc)
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular season stats. He is also a lot
# fo fun to watch in the playoffs. Bowman should let JAgr have a lot of
# fun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final
# regular season game.          PENS RULE!!!

# %%
topics, probs = model.transform([new_doc])
# Out:
# C:\Users\jikim\anaconda3\lib\site-packages\scipy\sparse\_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
print('예측한 토픽 번호 :', topics)
# Out:
# 예측한 토픽 번호 : [-1]

# %% [markdown]
# # 9. 모델 저장과 로드

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
