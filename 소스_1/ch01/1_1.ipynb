# %% [markdown]
# # 수학과 파이썬 복습

# %% [markdown]
# ## 백터와 행렬

# %%
import numpy as np

l1 = [1,2,3]
print(type(l1))
print(l1.__class__)
x = np.array([1, 2, 3])
print(type(x))
print(x.__class__)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
x.shape
# Out:
# (3,)

# %%
x.ndim
# Out:
# 1

# %%
W = np.array([[1, 2, 3], 
              [4, 5, 6]])
W.shape
# Out:
# (2, 3)

# %%
W.ndim
# Out:
# 2

# %% [markdown]
# ## 행렬의 원소별 연산

# %%
W = np.array([1, 2, 3])
X = np.array([4, 5, 6])
W + X
# Out:
# array([5, 7, 9])

# %%
W * X
# Out:
# array([ 4, 10, 18])

# %%
W = np.array([[1, 2, 3], 
              [4, 5, 6]])
X = np.array([[0, 1, 2], 
              [3, 4, 5]])
W + X
# Out:
# array([[ 1,  3,  5],
#        [ 7,  9, 11]])

# %%
W * X
# Out:
# array([[ 0,  2,  6],
#        [12, 20, 30]])

# %% [markdown]
# ## 브로드 케스트

# %%
A = np.array([1, 2])
A * 10
# Out:
# array([10, 20])

# %%
A = np.array([[1, 2], 
              [3, 4]])
A * 10
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
A = np.array([[1, 2], 
              [3, 4]])
b = np.array([10, 20])
A * b
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ## 벡터의 내적과 행렬의 곱

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
print(np.dot(a, b))
print(np.sum(a*b))
# Out:
# 32
# 32

# %%
a = np.array([1, 2])
b = np.array([[1, 1, 1],
              [2, 2, 2]])
print(np.dot(a, b))
# Out:
# [5 5 5]

# %%
a = np.array([[1, 1, 1],
              [2, 2, 2]])
b = np.array([1, 2, 3])
print(np.dot(a, b))
# Out:
# [ 6 12]

# %%
A = np.array([[1, 2], 
              [3, 4]])
B = np.array([[5, 6], 
              [7, 8]])
np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A = np.array([[1, 2, 3], 
              [4, 5, 6]])
B = np.array([[1, 2], 
              [3, 4],
              [5, 6]])
np.dot(A, B)  # (2,3)(3,2)
# Out:
# array([[22, 28],
#        [49, 64]])
